# %% [markdown]
# # Telegram bot

# %% [markdown]
# Telegram-бот — это пользователь Telegram, который управляется программным кодом. Вот примеры реальных задач:

# %% [markdown]
# - 🚀 **Викторины, игры, тесты:** с ботом можно развлекаться.
# - 📝 **Планировщики задач и напоминания:** боты напоминают о дедлайнах (или о том, что вы их снова пропустили).
# - 📊 **Боты для бизнеса:** отправляют уведомления, принимают заказы, ведут статистику.
# - 💰 **Платежные системы:** принимают оплату.
# - 🤖 **Или просто веселятся:** "напиши боту - получишь мем".

# %% [markdown]
# # Типы Telegram-ботов 🤖
# ## — Чем они живут?
#
# 1. **Чат-боты:**
#    Они как виртуальные собеседники, которым никто не пишет... кроме вас.
#    Используются для общения в текстовом формате.
#
# 2. **Боты-сервис:**
#    Эти существуют ради нашего удобства. Пример: бот для заказа пиццы. 🍕
#
#
# 3. **Викторины и игры:**
#    Кто сказал, что бот-игра — это только «угадай слово»? Преферанс в массы!
#
# 4. **Интеграционные боты:**
#    - Взаимодействуют с внешними API (популярные: прогноз погоды, курсы валют).

# %% [markdown]
# ## Обзор библиотек для работы с Telegram

# %%
# А теперь познакомимся с библиотеками 📚
from IPython.display import Image
Image(url="https://i.imgflip.com/7wk1j3.jpg", width=500)  # Мем: "Когда кодить сложно, но за тебя всё делает библиотека"

print("""
Представляем 👇 три супер-библиотеки для написания Telegram-ботов. Вот их рейтинг:

1️⃣ **python-telegram-bot**
   - Плюсы: популярна, большая документация.
   - Минусы: мало настроена "на автомат", нужно писать структуры.

2️⃣ **telebot (PyTelegramBotAPI)**
   - Плюсы: идеальна для новичков — быстро и просто.
   - Минусы: тяжело масштабировать сложные проекты.

3️⃣ **aiogram**
   - Плюсы: поддержка асинхронности, мощь современного Python.
   - Минусы: сложнее для освоения новичками.

‼ Мы выберем библиотеку `PyTelegramBotAPI`. Почему? Потому что мне так захотелось).
""")
# Out:
# Представляем 👇 три супер-библиотеки для написания Telegram-ботов. Вот их рейтинг:
#
# 1️⃣ **python-telegram-bot**
#    - Плюсы: популярна, большая документация.
#    - Минусы: мало настроена "на автомат", нужно писать структуры.
#
# 2️⃣ **telebot (PyTelegramBotAPI)**
#    - Плюсы: идеальна для новичков — быстро и просто.
#    - Минусы: тяжело масштабировать сложные проекты.
#
# 3️⃣ **aiogram**
#    - Плюсы: поддержка асинхронности, мощь современного Python.
#    - Минусы: сложнее для освоения новичками.
#
# ‼ Мы выберем библиотеку `PyTelegramBotAPI`. Почему? Потому что мне так захотелось).

# %%
# !pip install pyTelegramBotAPI --quiet

print("Библиотека установлена! 🎉")
# Out:
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='pypi.org', port=443): Read timed out. (read timeout=15)")': /simple/pytelegrambotapi/
# Библиотека установлена! 🎉

# %%
TOKEN = 'ваш токен'

# %% [markdown]
# ###### мой Токен

# %%
TOKEN = "5095342266:AAF5r5OgBWJmHm7mSuQW298mbvYrgw4KVlo"

# %% [markdown]
# ## Создание первого простого бота

# %%
# Импортируем библиотеку
import telebot

# Здесь ваш токен (создайте бота заранее через BotFather)
TOKEN = TOKEN
bot = telebot.TeleBot(TOKEN)

print("Базовая настройка завершена. Ваш бот готов взаимодействовать!")
# Out:
# Базовая настройка завершена. Ваш бот готов взаимодействовать!

# %%
# Реакция на команду `/start`
@bot.message_handler(commands=['start'])
def send_welcome(message):
    bot.reply_to(message, "Привет, я твой новый бот! 🚀 Напиши /help, чтобы узнать, что я могу.")

print("Функция /start создана! Давайте проверим.")
# Out:
# Функция /start создана! Давайте проверим.

# %%
# Реакция на любое текстовое сообщение
@bot.message_handler(func=lambda message: True)
def echo_all(message):
    bot.reply_to(message, f"Ты написал: {message.text}")

print("Ого! Бот теперь отвечает на любые сообщения 😎.")
# Out:
# Ого! Бот теперь отвечает на любые сообщения 😎.

# %%
# Запуск бота
print("Запускаем бота... Напишите сообщение в чате!")
bot.polling()
# Out:
# Запускаем бота... Напишите сообщение в чате!

# %% [markdown]
# Проверяем - работает)

# %% [markdown]
# ## А Как это работает?

# %% [markdown]
# У нас три звена: наш компьютер с Python, сервер Телеграма и Телеграм-клиент.

# %% [markdown]
# На компьютере работает интерпретатор Python, а внутри интерпретатора крутится наша программа на Python. Она отвечает за весь контент: в неё заложены все шаблоны текста, вся логика, всё поведение.

# %% [markdown]
# Внутри программы на Python работает библиотека, которая отвечает за общение с сервером Телеграма. В библиотеку мы вшили секретный ключ, чтобы сервер Телеграма понимал, что наша программа связана с определённым ботом.

# %% [markdown]
# Когда клиент с Телеграмом запрашивает что то у бота , запрос приходит на сервер, а сервер отправляет его на наш компьютер. Запрос обрабатывается программой на Python, ответ идёт на сервер Телеграма, сервер отдаёт ответ клиенту. Изи:

# %% [markdown]
# Обратите внимание, что работать наш бот будет только тогда, когда включён компьютер и на нём запущена программа на Python. Если компьютер выключится, пропадёт интернет или вы отключите интерпретатор, то бот работать перестанет: запросы будут приходить, но никто на них не ответит

# %% [markdown]
# #### Что будем дальше?

# %% [markdown]
#     1 Регистрируем бота в Телеграме.
#     2 Устанавливаем Python-библиотеку для работы с Телеграмом.
#     3 Добавляем библиотеку в программу  и учим программу реагировать на сообщения в чате.
#
#
#     4 Пишем там же код, который покажет кнопки
#     5 Делаем несколько мини-проектов

# %% [markdown]
# **Основные элементы:**
# 1️⃣ **Библиотека создаёт объект "бота".**
#    Этот объект понимает команды, сообщения и отвечает пользователям.
#
# 2️⃣ **Взаимодействие строится на "хендлерах".**
#    Хендлер — это "обработчик".
#    Он определяет, как бот будет реагировать на действия.
#
# **Простыми словами:**
# - Кто-то написал боту `/start` → Хендлер ловит эту команду → Вызывается специальная функция.
# - Кто-то прислал любое текстовое сообщение → Его тоже ловит хендлер → Применяется другая функция.

# %% [markdown]
# #### Типы хендлеров в pyTelegramBotAPI

# %% [markdown]
# # Какие бывают хендлеры? 🛠️
# Большинство действий обрабатывается через хендлеры. Вот основные из них:
#
# 1️⃣ Хендлеры для команд:
#    Например, `/start`, `/help`. Обрабатываются через `@bot.message_handler(commands=['name'])`.
#
# 2️⃣ Хендлер для текста:
#    Бот ловит любые текстовые сообщения. Обрабатывается через `func=lambda message: True`.
#
# 3️⃣ Хендлеры для типов сообщений:
#    Например, бот реагирует только на **фотографии, видео, аудио**.
#    Используется `@bot.message_handler(content_types=['photo', 'video', 'audio'])`.
#
# 4️⃣ Пользовательские фильтры:
#    Можно настроить **условия** для обработки сообщений. Например:
#    - Только текст, содержащий конкретное слово.
#    - Только сообщения определённых пользователей.
#
# ‼️ Таких хендлеров можно использовать несколько. Главное — порядок вызова:
# Когда бот видит сообщение, он проверяет его по очереди через регистрацию хендлеров.

# %% [markdown]
# # Как работает бот? 🤨
#
# 1️⃣ Пользователь взаимодействует с ботом: пишет команду или сообщение.
# 2️⃣ Бот **получает событие (update)** от Telegram с информацией о сообщении.
# 3️⃣ Библиотека через цепочку хендлеров находит подходящую функцию.
# 4️⃣ Запускается ваш код.

# %%
# Импортируем библиотеку
import telebot

# Токен для доступа к боту
TOKEN = TOKEN
bot = telebot.TeleBot(TOKEN)

# Пояснение:
#  - telebot.TeleBot — это главный объект, наше "сердце бота".
#  - Через этот объект мы добавляем хендлеры и обрабатываем события.

# %%
# Реакция на команду /start
@bot.message_handler(commands=['start'])
def send_welcome(message):
    bot.reply_to(message, "Привет! Я бот, который научит тебя писать ботов 🚀\nНапиши /help, чтобы узнать команды.")

# Пояснение:
#  - @bot.message_handler(commands=['название команды']) — "ловим" команду.
#  - Когда юзер введёт команду, вызовется функция send_welcome.
#  - В функции:
#      - message хранит инфу о сообщении пользователя.
#      - bot.reply_to отправляет ответ в чат.

# %%
# Реакция на текстовые сообщения
@bot.message_handler(func=lambda message: True)
def echo_message(message):
    bot.reply_to(message, f"Ты сказал: {message.text}. Какой интересный текст! 🙃")

# Пояснение:
# - func=lambda message: True — указывает, что этот хендлер будет реагировать на любое сообщение.
# - bot.reply_to — отвечает на сообщение.

# %%
# Запуск бота
print("Бот готов и ждёт сообщения...")
bot.polling()
# Out:
# Бот готов и ждёт сообщения...

# %% [markdown]
# Теперь бот будет:
#
# Реагировать на команду /start приветствием.
# Повторять за пользователем любое сообщение (эмуляция "эхо-бота").

# %% [markdown]
# ## Давайте добавим встроенную клавиатуру

# %% [markdown]
# # Как работает клавиатура?
# Клавиатура позволяет добавлять кнопки, которые видны прямо внутри чата.
# Пользователь нажимает на кнопку, а сообщение отправляется как будто он написал его вручную.
#
# **Типы клавиатуры:**
# 1️⃣ **ReplyKeyboardMarkup** (стандартная клавиатура):
#    - Показывается снизу чата.
#    - Это базовые текстовые кнопки.
#
# 2️⃣ **InlineKeyboardMarkup** (инлайн-кнопки):
#    - Показываются прямо в сообщении.
#    - У каждой кнопки есть действие, которое можно обработать без отправки команды.
#
# 📌 Мы добавим **ReplyKeyboardMarkup** — простую клавиатуру.

# %%
# Импортируем необходимые классы
from telebot.types import ReplyKeyboardMarkup, KeyboardButton

# Добавляем команду для отображения клавиатуры
@bot.message_handler(commands=['keyboard'])
def show_keyboard(message):
    # Создаём объект клавиатуры
    markup = ReplyKeyboardMarkup(resize_keyboard=True, row_width=2)
    # Добавляем кнопки
    button1 = KeyboardButton('Кнопка 1')
    button2 = KeyboardButton('Кнопка 2')
    markup.add(button1, button2)
    # Отправляем сообщение с клавиатурой
    bot.send_message(message.chat.id, "Вот твоя клавиатура👇", reply_markup=markup)

# Пояснение:
#  - resize_keyboard=True — кнопки адаптируются под размер экрана.
#  - row_width=2 — кнопки идут по 2 в ряд.

# %%
# После запуска попробуйте в чате отправить команду /keyboard.
print("Готово! Напишите /keyboard, чтобы увидеть клавиатуру.")
bot.polling()
# Out:
# Готово! Напишите /keyboard, чтобы увидеть клавиатуру.

# %% [markdown]
# ###### Проверяем.... и не работает

# %% [markdown]
# Проблема в том, что команда /keyboard обрабатывается общим хендлером для текстовых сообщений из-за его настройки func=lambda message: True. Этот хендлер срабатывает на всё, включая команды. Нам нужно изменить порядок регистрации хендлеров в коде, чтобы хендлер для команды /keyboard обрабатывался правильно раньше общего текстового хендлера.
#
# Давайте исправим код и разберём логику:

# %%
# Импортируем необходимые модули
import telebot
from telebot.types import ReplyKeyboardMarkup, KeyboardButton

# Токен вашего бота
TOKEN = TOKEN
bot = telebot.TeleBot(TOKEN)

# Хендлер для команды /start
@bot.message_handler(commands=['start'])
def send_welcome(message):
    bot.reply_to(message, "Привет! Я бот, который научит тебя писать ботов 🚀\nНапиши /keyboard, чтобы посмотреть на клавиатуру!")

# Хендлер для команды /keyboard
@bot.message_handler(commands=['keyboard'])
def show_keyboard(message):
    # Создаём клавиатуру
    markup = ReplyKeyboardMarkup(resize_keyboard=True, row_width=2)
    button1 = KeyboardButton('Кнопка 1')
    button2 = KeyboardButton('Кнопка 2')
    markup.add(button1, button2)
    # Отправляем сообщение с клавиатурой
    bot.send_message(message.chat.id, "Вот твоя клавиатура:", reply_markup=markup)

# Общий хендлер для любых других текстовых сообщений
@bot.message_handler(func=lambda message: True)
def echo_all(message):
    bot.reply_to(message, f"Ты сказал: {message.text}. Какой интересный текст! 🙃")

# Запускаем бот
print("Бот запущен. Откройте Telegram и взаимодействуйте с ботом!")
bot.polling()
# Out:
# Бот запущен. Откройте Telegram и взаимодействуйте с ботом!

# %% [markdown]
# Почему работало неправильно?
# Порядок регистрации хендлеров:
# Хендлеры в библиотеке pyTelegramBotAPI обрабатываются в том порядке, в котором они зарегистрированы.
# Хендлер func=lambda message: True (на все текстовые сообщения) "перехватывал" даже команду /keyboard, т.к. она тоже считается текстовым сообщением.
# Этот общий текстовый хендлер стоит регистрировать последним , чтобы дать приоритет другим (например, команде /keyboard).
# Теперь хендлер для /keyboard обрабатывается раньше общего текстового хендлера , и клавиатура корректно выводится.

# %% [markdown]
# #### Альтернативные примеры:

# %% [markdown]
# ###### ЭХО-БОТ

# %% [markdown]
# Для начала реализуем так называемого эхо‑бота. Он будет получать от пользователя текстовое сообщение и возвращать его.

# %%
# !pip install pytelegrambotapi
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import telebot
# Создаем экземпляр бота
bot = telebot.TeleBot(TOKEN)
# Функция, обрабатывающая команду /start
@bot.message_handler(commands=["start"])
def start(m, res=False):
    bot.send_message(m.chat.id, 'Я на связи. Напиши мне что-нибудь )')
# Получение сообщений от юзера
@bot.message_handler(content_types=["text"])
def handle_text(message):
    bot.send_message(message.chat.id, 'Вы написали: ' + message.text)
# Запускаем бота
bot.polling(none_stop=True, interval=0)

# %%
import telebot
# Создаем экземпляр бота
bot = telebot.TeleBot(TOKEN)
# Функция, обрабатывающая команду /start
@bot.message_handler(commands=["start"])
def start(m, res=False):
    bot.send_message(m.chat.id, 'Я на связи. Напиши мне что-нибудь )')
# Получение сообщений от юзера
@bot.message_handler(content_types=["text"])
def handle_text(message):
    bot.send_message(message.chat.id, 'Вы написали: ' + message.text)
    print('*********')
	print(message)
	print('########')
	print(message.chat.id)
	print('########')
	print(message.text)
	print('$$$$$$$$$')
# Запускаем бота
bot.polling(none_stop=True, interval=0)
# Out:
#   Cell In[33], line 13
#     print(message)
#     ^
# TabError: inconsistent use of tabs and spaces in indentation

# %%
import telebot
# Создаем экземпляр бота
bot = telebot.TeleBot(TOKEN)
# Функция, обрабатывающая команду /start
@bot.message_handler(commands=["start"])
def start(m, res=False):
    bot.send_message(m.chat.id, 'Я на связи. Напиши мне что-нибудь )')
# Получение сообщений от юзера
@bot.message_handler(content_types=["text"])
def handle_text(message):
    bot.send_message(message.chat.id, 'Вы написали: ' + message.text)
    print('*********')
    print(message)
    print('########')
    print(message.chat.id)
    print('########')
    print(message.text)
    print('$$$$$$$$$')
# Запускаем бота
bot.polling(none_stop=True, interval=0)
# Out:
# *********
# ...

# %% [markdown]
# https://xakep.ru/2021/11/28/python-telegram-bots/

# %% [markdown]
# ##### Усложняем нашего базового бота

# %%
# Импортируем необходимые модули
import telebot
from telebot.types import ReplyKeyboardMarkup, KeyboardButton
from telebot.types import InlineKeyboardMarkup, InlineKeyboardButton

# Токен вашего бота
TOKEN = TOKEN
bot = telebot.TeleBot(TOKEN)

# Хендлер для команды /start
@bot.message_handler(commands=['start'])
def send_welcome(message):
    bot.reply_to(message, "Привет! Я бот, который научит тебя писать ботов 🚀\nНапиши /keyboard, чтобы посмотреть на клавиатуру!")

# Хендлер для команды /keyboard
@bot.message_handler(commands=['keyboard'])
def show_keyboard(message):
    # Создаём клавиатуру
    markup = ReplyKeyboardMarkup(resize_keyboard=True, row_width=2)
    button1 = KeyboardButton('Кнопка 1')
    button2 = KeyboardButton('Кнопка 2')
    markup.add(button1, button2)
    # Отправляем сообщение с клавиатурой
    bot.send_message(message.chat.id, "Вот твоя клавиатура:", reply_markup=markup)

# Хендлер для сообщений с определённым словом "привет"
@bot.message_handler(func=lambda message: "привет" in message.text.lower())
def greet_user(message):
    bot.reply_to(message, "Привет, рад тебя видеть! 🙌")

# Пояснение:
# - message.text.lower() — приводим текст сообщения в нижний регистр, чтобы обработать "Привет", "пРИВЕТ", и т.д.
# - Хендлер реагирует только на сообщения, где есть "привет".


# Хендлер для команды /vote, чтобы отправить сообщение с кнопками
@bot.message_handler(commands=['vote'])
def send_vote_buttons(message):
    markup = InlineKeyboardMarkup()
    button1 = InlineKeyboardButton("👍 Лайк", callback_data="vote_like")
    button2 = InlineKeyboardButton("👎 Дизлайк", callback_data="vote_dislike")
    markup.add(button1, button2)
    bot.send_message(message.chat.id, "Как вам этот бот?", reply_markup=markup)

# Пояснение:
# - InlineKeyboardMarkup() создаёт разметку "инлайн"-кнопок.
# - callback_data="..." — данные, которые бот получит при нажатии кнопки.

# Обработка нажатий на кнопки
@bot.callback_query_handler(func=lambda call: True)
def handle_vote(call):
    if call.data == "vote_like":
        bot.answer_callback_query(call.id, "Вы поставили лайк. Спасибо! 😊")
    elif call.data == "vote_dislike":
        bot.answer_callback_query(call.id, "Вы поставили дизлайк. Мы учтём ваше мнение. 😔")



# Общий хендлер для любых других текстовых сообщений
@bot.message_handler(func=lambda message: True)
def echo_all(message):
    bot.reply_to(message, f"Ты сказал: {message.text}. Какой интересный текст! 🙃")

# Запускаем бот
print("Бот запущен. Откройте Telegram и взаимодействуйте с ботом!")
bot.polling()
# Out:
# Бот запущен. Откройте Telegram и взаимодействуйте с ботом!

# %% [markdown]
# Давайте доработаем пример с инлайн-кнопками так, чтобы при нажатии кнопки "Дизлайк" в консоль выводился никнейм или имя пользователя, если никнейм не указан.

# %%
# Импортируем необходимые модули
import telebot
from telebot.types import ReplyKeyboardMarkup, KeyboardButton
from telebot.types import InlineKeyboardMarkup, InlineKeyboardButton

# Токен вашего бота
TOKEN = TOKEN
bot = telebot.TeleBot(TOKEN)

# Хендлер для команды /start
@bot.message_handler(commands=['start'])
def send_welcome(message):
    bot.reply_to(message, "Привет! Я бот, который научит тебя писать ботов 🚀\nНапиши /keyboard, чтобы посмотреть на клавиатуру!")

# Хендлер для команды /keyboard
@bot.message_handler(commands=['keyboard'])
def show_keyboard(message):
    # Создаём клавиатуру
    markup = ReplyKeyboardMarkup(resize_keyboard=True, row_width=2)
    button1 = KeyboardButton('Кнопка 1')
    button2 = KeyboardButton('Кнопка 2')
    markup.add(button1, button2)
    # Отправляем сообщение с клавиатурой
    bot.send_message(message.chat.id, "Вот твоя клавиатура:", reply_markup=markup)

# Хендлер для сообщений с определённым словом "привет"
@bot.message_handler(func=lambda message: "привет" in message.text.lower())
def greet_user(message):
    bot.reply_to(message, "Привет, рад тебя видеть! 🙌")

# Пояснение:
# - message.text.lower() — приводим текст сообщения в нижний регистр, чтобы обработать "Привет", "пРИВЕТ", и т.д.
# - Хендлер реагирует только на сообщения, где есть "привет".


# Хендлер для команды /vote, чтобы отправить сообщение с кнопками
@bot.message_handler(commands=['vote'])
def send_vote_buttons(message):
    markup = InlineKeyboardMarkup()
    button1 = InlineKeyboardButton("👍 Лайк", callback_data="vote_like")
    button2 = InlineKeyboardButton("👎 Дизлайк", callback_data="vote_dislike")
    markup.add(button1, button2)
    bot.send_message(message.chat.id, "Как вам этот бот?", reply_markup=markup)

# Пояснение:
# - InlineKeyboardMarkup() создаёт разметку "инлайн"-кнопок.
# - callback_data="..." — данные, которые бот получит при нажатии кнопки.

# Обработка нажатий на кнопки
# @bot.callback_query_handler(func=lambda call: True)
# def handle_vote(call):
#     if call.data == "vote_like":
#         bot.answer_callback_query(call.id, "Вы поставили лайк. Спасибо! 😊")
#     elif call.data == "vote_dislike":
#         bot.answer_callback_query(call.id, "Вы поставили дизлайк. Мы учтём ваше мнение. 😔")


# Обработка нажатий на кнопки
@bot.callback_query_handler(func=lambda call: True)
def handle_vote(call):
    if call.data == "vote_like":
        bot.answer_callback_query(call.id, "Вы поставили лайк. Спасибо! 😊")
    elif call.data == "vote_dislike":
        # Получаем информацию о пользователе
        user = call.from_user
        username = user.username or f"{user.first_name} {user.last_name or ''}"

        # Логируем в консоль
        print(username, "мудак")

        bot.answer_callback_query(call.id, "Вы поставили дизлайк. Мы учтём ваше мнение. 😔")



# Общий хендлер для любых других текстовых сообщений
@bot.message_handler(func=lambda message: True)
def echo_all(message):
    bot.reply_to(message, f"Ты сказал: {message.text}. Какой интересный текст! 🙃")

# Запускаем бот
print("Бот запущен. Откройте Telegram и взаимодействуйте с ботом!")
bot.polling()
# Out:
# Бот запущен. Откройте Telegram и взаимодействуйте с ботом!
# Dan_Cherni мудак
# Dan_Cherni мудак
# Dan_Cherni мудак

# %% [markdown]
# #### Добавим еще всяких штук

# %%
# Импортируем необходимые модули
import telebot
from telebot.types import ReplyKeyboardMarkup, KeyboardButton
from telebot.types import InlineKeyboardMarkup, InlineKeyboardButton
import random

# Токен вашего бота
TOKEN = TOKEN
bot = telebot.TeleBot(TOKEN)

# Хендлер для команды /start
@bot.message_handler(commands=['start'])
def send_welcome(message):
    bot.reply_to(message, "Привет! Я бот, который научит тебя писать ботов 🚀\nНапиши /keyboard, чтобы посмотреть на клавиатуру!")

# Хендлер для команды /keyboard
@bot.message_handler(commands=['keyboard'])
def show_keyboard(message):
    # Создаём клавиатуру
    markup = ReplyKeyboardMarkup(resize_keyboard=True, row_width=2)
    button1 = KeyboardButton('Кнопка 1')
    button2 = KeyboardButton('Кнопка 2')
    markup.add(button1, button2)
    # Отправляем сообщение с клавиатурой
    bot.send_message(message.chat.id, "Вот твоя клавиатура:", reply_markup=markup)

# Хендлер для сообщений с определённым словом "привет"
@bot.message_handler(func=lambda message: "привет" in message.text.lower())
def greet_user(message):
    bot.reply_to(message, "Привет, рад тебя видеть! 🙌")

# Пояснение:
# - message.text.lower() — приводим текст сообщения в нижний регистр, чтобы обработать "Привет", "пРИВЕТ", и т.д.
# - Хендлер реагирует только на сообщения, где есть "привет".


# Хендлер для команды /vote, чтобы отправить сообщение с кнопками
@bot.message_handler(commands=['vote'])
def send_vote_buttons(message):
    markup = InlineKeyboardMarkup()
    button1 = InlineKeyboardButton("👍 Лайк", callback_data="vote_like")
    button2 = InlineKeyboardButton("👎 Дизлайк", callback_data="vote_dislike")
    markup.add(button1, button2)
    bot.send_message(message.chat.id, "Как вам этот бот?", reply_markup=markup)

# Пояснение:
# - InlineKeyboardMarkup() создаёт разметку "инлайн"-кнопок.
# - callback_data="..." — данные, которые бот получит при нажатии кнопки.

# Обработка нажатий на кнопки
@bot.callback_query_handler(func=lambda call: True)
def handle_vote(call):
    if call.data == "vote_like":
        bot.answer_callback_query(call.id, "Вы поставили лайк. Спасибо! 😊")
    elif call.data == "vote_dislike":
        # Получаем информацию о пользователе
        user = call.from_user
        username = user.username or f"{user.first_name} {user.last_name or ''}"

        # Логируем в консоль
        print(username, "мудак")

        bot.answer_callback_query(call.id, "Вы поставили дизлайк. Мы учтём что вы ..... 😔")

# Команда /random — бот отвечает случайным числом от 1 до 100
@bot.message_handler(commands=['random'])
def send_random(message):
    number = random.randint(1, 100)
    bot.reply_to(message, f"👾 Твоё случайное число: {number}")

# Хендлер для команды /meme
@bot.message_handler(commands=['meme'])
def send_meme(message):
    # Пример URL картинки
    meme_url = "https://imgflip.com/i/9do8n9"
    bot.send_photo(message.chat.id, meme_url, caption="Вот твой мем! ")

# Хендлер для команды /file
@bot.message_handler(commands=['file'])
def send_file(message):
    with open("явки пароли адреса.txt", "rb") as file:  # Замените на путь к вашему файлу
        bot.send_document(message.chat.id, file, caption="Держи секретный файл 📄")

# Хендлер для команды /info
@bot.message_handler(commands=['info'])
def send_user_info(message):
    user = message.from_user
    response = (
        f"👤 Информация о тебе:\n"
        f"Имя: {user.first_name}\n"
        f"Фамилия: {user.last_name or 'Не указана'}\n"
        f"Логин: @{user.username or 'Не указан'}\n"
        f"ID: {user.id}"
    )
    bot.reply_to(message, response)

# Хендлер для обработки стикеров
@bot.message_handler(content_types=['sticker'])
def sticker_reaction(message):
    bot.reply_to(message, "Ого, классный стикер! 😎")
# Хендлер для сообщений с определённым словом "привет"
@bot.message_handler(func=lambda message: "привет" in message.text.lower())
def greet_user(message):
    bot.reply_to(message, "Шалом, рад тебя видеть! 🙌")

# Команда /help
@bot.message_handler(commands=['help'])
def send_help(message):
    commands = """
Доступные команды:
👋 /start - Начать общение с ботом.
📊 /vote - Голосование.
🎲 /random - Получить случайное число.
🕹️ /game - Угадай число.
🖼️ /meme - Получить мем.
📝 /info - Узнать информацию о себе.
📂 /file - Получить пример файла.
    """
    bot.reply_to(message, commands)
# Пояснение:
# - message.text.lower() — приводим текст сообщения в нижний регистр, чтобы обработать "Привет", "пРИВЕТ", и т.д.
# - Хендлер реагирует только на сообщения, где есть "привет".

# Общий хендлер для любых других текстовых сообщений
@bot.message_handler(func=lambda message: True)
def echo_all(message):
    bot.reply_to(message, f"Ты сказал: {message.text}. Какой интересный текст! 🙃")

# Запускаем бот
print("Бот запущен. Откройте Telegram и взаимодействуйте с ботом!")
bot.polling()
# Out:
# Бот запущен. Откройте Telegram и взаимодействуйте с ботом!

# %% [markdown]
# # ПРАААААААКТИКА

# %% [markdown]
# # Вы сотрудники компании Horns and Hooves International Technologies и к вам пришел Самый Главный и Лысый Очень

# %% [markdown]
# # Утром он (гендир)  увидел письмо в спаме
#
# Письмо было из вуза, где он когда-то учился:
#
# > *"Наша компания хочет перейти на использование современного решения для оповещения студентов о расписании занятий.
# Мы решили работать с **Horns and Hooves International Technology**, потому что все ваши проекты — прямо космос 🚀."*
#
# В письме было вложение с ТЗ на проект:
#
# ---
#
# ## **Техническое задание**
#
# ### **Основной функционал MVP**
# 1. В Telegram-боте должна быть:
#     * Возможность загрузки файла с расписанием в формате CSV (должен загружаться как в групповые, так и в личные чаты).
#     * Функционал для выбора номера группы для фильтрации расписания.
#     * Функция выдачи расписания группы по запросу.
#
# 2. **Уведомления:**
#     * Студенты должны получать уведомление за 1 час до начала занятия.
#     * При этом уведомления должны приходить только нужным пользователям, а не всем сразу.
#
# ---
#
# ### **Будущее масштабирование**
# Мы планируем сделать гибкую систему! Она должна поддерживать:
#
# * Интеграцию с почтовым сервисом (например, уведомления через email).
# * Добавление персональных занятий для отдельных студентов, чтобы учитывать репетиторство или другие активности не из общего расписания.
# * 💥 Кастомизацию уведомлений: например, чтобы студент мог выбрать, за сколько времени до лекции получить уведомление (1 час, 30 минут и т.д.).
# * Возможность новых визуальных шаблонов расписаний.
#
# **‼️ Важно:** кастомизацией должны управлять сами студенты через Telegram (в дальнейшем, через web-интерфейс).
#
# ---
#
# ### **Другие пожелания**
# 1. **Котики.**
#     Да, мы хотим, чтобы чат-бот умел радовать студентов котиками. Например, если они задерживаются к занятиям, бот может украшать сообщение картинкой котика 🙀.
#
# 2. **Глобальная база расписаний и персонализация:**
#     Мы хотим, чтобы в будущем расписания хранились централизованно (например, в облаке или базе данных).
#
# 3. **Скорость разработки:**
#     ✅ Для MVP важна максимальная простота, но мы не хотим дублировать данные (например, нельзя, чтобы каждый преподаватель загружал свои расписания в бота).
#
# ---
#
# ### **Контроль**
#
# 1. **Приемка решения:**
#     Сначала мы протестируем MVP на пятничной паре студентах групп "404" (они постоянно теряются) и "408" (а эти постоянно опаздывают, да так что иногда не приходят совсем).
#     Если решение утвердится, применим его во всем ВУЗе.
#
# 2. **Документация:**
#     От вас требуется:
#     * Техническая документация,
#     * Проектная спецификация (ЧТЗ, архитектура),
#     * План внедрения,
#     * Тест-кейсы.
#
# ---
#
# ### **Мы ждём хороший Python-код (не ниже 2.4) и котиков 😉.**

# %%
1. Как сейчас хранится расписание?
2. Количество курсов/групп
3. Контакты студентов
4. Пример данных
5. Есть ли у вас сервер для раоты бота/ представление о деплое
6. Хранение данных
7. Кто такие нужные пользователи?
8. Как индетифицировать пользователя?
9. Котики сейчас или потом?

# %%
/joingroup 404
/joingroup 408

# %% [markdown]
#  **Цель проекта:**

# %%
 Система уведомлений для студентов
    1) Выдать расписание на неделю
    2) Нотификация о занятии с названием пары временем и аудиторией

# %%
    - Этап 1: уточнение требований (анализ файла с расписанием).
   - Этап 2: Разработка бота (ключевой функционал).
   - Этап 3: Тестирование.
   - Этап 4: Презентация и приёмка.

# %%
 **Сроки:**
    2 часа

# %%
Ограничения:
    Периметр проекта: 2 группы
    Нотификация за 1 час без смены интервала.
    Корректность файла с расписанием на стороне заказчика.

# %%
**Риски проекта:**
    срок предоставления документов
    измение структуры и неймига не предполагаются

# %%
*Бюджет:** 3000 "рогов/копыт

# %%
Система должна обрабатывать файл xls.

# %%
    0) Обработчик ексел файл
    1) Выдать расписание на неделю
    2) Нотификация о занятии с названием пары временем и аудиторией

# %%
/schedule404
/schedule408

# %% [markdown]
# ## ДЗ

# %%
pip install telebot
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.1/48.1 kB 2.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 270.5/270.5 kB 7.3 MB/s eta 0:00:00
# ...

# %%
import telebot
import requests

# %% [markdown]
# 1. Написать бота который будет проверять доступность сайта

# %%
TOKEN = "7904803865:AAEuZO-Uk4YopjiZWLD-aKfJZz7PcNlRLbs"
bot = telebot.TeleBot(TOKEN)

# %%
@bot.message_handler(commands=['start', 'help'])
def send_welcome(message):
    bot.reply_to(message, "Привет! Отправь мне URL, и я проверю его доступность.")

@bot.message_handler(func=lambda message: True)
def check_website(message):
    url = message.text.strip()
    if not url.startswith("http"):
        url = "http://" + url

    try:
        response = requests.get(url, timeout=5)
        if response.status_code == 200:
            bot.reply_to(message, f"Сайт {url} доступен (код {response.status_code}).")
        else:
            bot.reply_to(message, f"Сайт {url} вернул код {response.status_code}.")
    except requests.RequestException:
        bot.reply_to(message, f"Не удалось подключиться к {url}.")

bot.polling()

# %% [markdown]
# *Скрины к выполненному заданию*

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 2. Написать бота который будет анализировать текст - (Статистика, количество уникальных слов, самые популярные слова, кроме союзов и предлогов, количество предложений)

# %%
pip install pyTelegramBotAPI nltk

# %%
import nltk
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
import nltk
nltk.data.path.append('/usr/local/nltk_data')
nltk.download('punkt', download_dir='/usr/local/nltk_data')
nltk.download('stopwords', download_dir='/usr/local/nltk_data')
# Out:
# [nltk_data] Downloading package punkt to /usr/local/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /usr/local/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
TOKEN = "7549496426:AAEZDDlE1w7urRs_0z6fcI5SvnMrFjsMWVQ"
bot = telebot.TeleBot(TOKEN)

# %%
import telebot
import nltk
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from collections import Counter
import string

stop_words = set(stopwords.words("russian"))

@bot.message_handler(commands=['start', 'help'])
def send_welcome(message):
    bot.reply_to(message, "Привет! Отправь мне текст, и я проанализирую его.")

@bot.message_handler(func=lambda message: True)
def analyze_text(message):
    text = message.text

    sentences = sent_tokenize(text, language="russian")
    words = word_tokenize(text, language="russian")

    words = [word.lower() for word in words if word.isalnum()]

    filtered_words = [word for word in words if word not in stop_words]

    total_words = len(words)
    unique_words = len(set(filtered_words))
    total_sentences = len(sentences)

    word_freq = Counter(filtered_words)
    common_words = word_freq.most_common(5)

    result = (
        f"Статистика текста:\n"
        f"Количество предложений: {total_sentences}\n"
        f"Общее количество слов: {total_words}\n"
        f"Уникальных слов: {unique_words}\n\n"
        f"Топ-5 популярных слов:\n" +
        "\n".join([f"{word} — {count}" for word, count in common_words])
    )

    bot.reply_to(message, result)

bot.polling()
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# <ipython-input-13-9551e3f3f9d9> in <cell line: 0>()
#      41     bot.reply_to(message, result)
#      42
# ---> 43 bot.polling()
#
# /usr/local/lib/python3.11/dist-packages/telebot/__init__.py in polling(self, non_stop, skip_pending, interval, timeout, long_polling_timeout, logger_level, allowed_updates, none_stop, restart_on_change, path_to_watch)
#    1196
#    1197         if self.threaded:
# -> 1198             self.__threaded_polling(non_stop=non_stop, interval=interval, timeout=timeout, long_polling_timeout=long_polling_timeout,
#    1199                                     logger_level=logger_level, allowed_updates=allowed_updates)
#    1200         else:
#
# ...

# %% [markdown]
# *Запустил код локально из-за проблем с nltk*

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 3. Бот калькулятор
# *с кнопками

# %%
TOKEN = "7998047482:AAFy2y__wy-Bhi1QWpgLv9sGFtCl67ODtrE"
bot = telebot.TeleBot(TOKEN)

# %%
from telebot.types import InlineKeyboardMarkup, InlineKeyboardButton


user_data = {}

def generate_keyboard():
    keyboard = InlineKeyboardMarkup(row_width=4)
    buttons = [
        "7", "8", "9", "/",
        "4", "5", "6", "*",
        "1", "2", "3", "-",
        "0", ".", "=", "+",
        "C"
    ]
    keyboard.add(*[InlineKeyboardButton(text=symbol, callback_data=symbol) for symbol in buttons])
    return keyboard

@bot.message_handler(commands=['start'])
def start(message):
    user_data[message.chat.id] = ""
    bot.send_message(message.chat.id, "0", reply_markup=generate_keyboard())

@bot.callback_query_handler(func=lambda call: True)
def handle_query(call):
    chat_id = call.message.chat.id
    data = call.data

    if data == "C":
        user_data[chat_id] = ""
        bot.edit_message_text(chat_id=chat_id, message_id=call.message.message_id, text="0", reply_markup=generate_keyboard())
    elif data == "=":
        try:
            result = str(eval(user_data[chat_id]))
            user_data[chat_id] = result
        except Exception:
            result = "Ошибка"
            user_data[chat_id] = ""
        bot.edit_message_text(chat_id=chat_id, message_id=call.message.message_id, text=result, reply_markup=generate_keyboard())
    else:
        user_data[chat_id] += data
        bot.edit_message_text(chat_id=chat_id, message_id=call.message.message_id, text=user_data[chat_id], reply_markup=generate_keyboard())

if __name__ == "__main__":
    bot.polling(none_stop=True)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
