# %% [markdown]
# # УРОК 1

# %% [markdown]
# ### План Занятия:

# %% [markdown]
# #### ~~1 Знакомство~~
# #### ~~2 Аналитика~~
# #### ~~3 Монти Пайтон и друзья~~
# #### ~~4 Работа с Пайтоном~~
# #### 5 Типы данных (базовые)
# #### 6 Первые действия (математика)
# #### 7 Преобразование типов
# #### 8 Сохраняем наш код и выполняем его

# %% [markdown]
# # Установка Python

# %% [markdown]
# ### Установка Python и pip на Windows

# %% [markdown]
# Лучший способ установить Python на Windows — это скачать официальный установщик с сайта python.org. Чтобы сделать это, откройте браузер и перейдите по ссылке https://python.org/.

# %% [markdown]
# Запускаем установщик Python

# %% [markdown]
# Обязательно установите флажок на «Add Python X.Y to PATH» в мастере настройке. Убедитесь, что флажок “Add Python X.Y to PATH” поставлен в установщике, в противном случае у вас будут проблемы с доступом инсталлятора Python к командной стоке. Нажмите «Установить» для начала установки.

# %% [markdown]
#  Давайте убедимся в том, что все было выполнено правильно, протестировав, имеет ли Python доступ к командной строке (cmd) Windows:

# %% [markdown]
# https://tutorial.djangogirls.org/ru/python_installation/

# %% [markdown]
# ## Sublime Text

# %% [markdown]
# Зачем устанавливать отдельную программу для редактирования кода, если можно использовать Word или Notepad?
#
# Во-первых, код должен должен храниться в виде простого текста, а проблема таких программ, как Word или Textedit в том, что они не сохраняют файлы в этом виде, а используют "обогащённый" текст (с форматированием и шрифтами), например, RTF (Rich Text Format).
#
# Вторая причина в том, что специализированные редакторы предоставляют множество полезных для программирования возможностей, таких как цветная подсветка кода в зависимости от его смысла и автоматически закрывающиеся кавычки.

# %% [markdown]
# ## Jupyter notebook - ANACONDA и WSL

# %% [markdown]
# https://pythonru.com/baza-znanij/kak-ustanovit-anaconda-na-windows

# %%
wsl.exe --install

# %%
sudo apt update
sudo apt upgrade

# %%
sudo apt install python3-pip python3-dev

# %%
sudo -H pip3 install --upgrade pip
sudo -H pip3 install virtualenv

# %%
mkdir env
cd env

# %%
virtualenv env

# %%
source env/bin/activate

# %%
pip install jupyter

# %%
jupyter notebook

# %% [markdown]
# A few things before we start:
#
# Автор тетрадки: Воробьев Даниил @herrenot
# Использовались очевидные заимствования отовсюду подряд, материал никак не претендует на уникальность. Однако, любые опечатки и неточности, конечно же, исключительно на моей совести
# Тут подразумевается Python3.7 и 3.8, скорее всего что-то не будет работать с более ранними версиями
# Я мало пишу на русском. Замечания про опечатки, отсутствующие запятые и несогласованные предложения приветствуются

# %% [markdown]
# Тут можно писать комментарии в языке Markdown, это такая разметка.
#
# Среда называется jupyter notebook. Мы подробно про неё поговорим попозже

# %% [markdown]
# ## Типы данных (базовые)

# %% [markdown]
#     Базовых типов в питоне немного.
#     Это str, float, int, complex, boolean. Булевый самый простой и с ним можно использовать всякие операции

# %% [markdown]
#     Python – язык со строгой динамической типизацией.
#     Т.е. тип используемой переменной трактуется в зависимости от значения, при этом не допускается неявное преобразование (например, сложение строки и числа).

# %% [markdown]
# ### int

# %% [markdown]
# INT - это просто целые числа. Вы можете складывать (+), вычитать (-), умножать (*) и делить (/) целые числа в Python.

# %%
2+2
# Out:
# 4

# %%
2*3
# Out:
# 6

# %%
12345678 * 987654328765432318765
# Out:
# 12193262318244164938266047670

# %%
2**2
# Out:
# 4

# %%
10 - 5
# Out:
# 5

# %%
3 + 5 * 4
# Out:
# 23

# %%
3 + 5 * 4
# Out:
# 23

# %%
40 // 8
# Out:
# 5

# %%
40 / 8
# Out:
# 5.0

# %%
42 // 8
# Out:
# 5

# %%
42 % 8
# Out:
# 2

# %%
239 % 10
# Out:
# 9

# %%
- (42)
# Out:
# -42

# %%
+ (42)
# Out:
# 42

# %%
+-+42
# Out:
# -42

# %% [markdown]
# ### Сообщения об ошибках

# %%
-*42
# Out:
#   File "<ipython-input-13-761874de80cf>", line 1
#     -*42
#      ^
# SyntaxError: invalid syntax

# %%
+-+42
* 23
# Out:
#   File "<ipython-input-14-7b97d031da85>", line 2
#     * 23
#     ^
# SyntaxError: can't use starred expression here

# %%
5 // 0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-15-e6530c2158eb> in <module>
# ----> 1 5 // 0
#
# ZeroDivisionError: integer division or modulo by zero

# %% [markdown]
# ### Числа с плавающей точкой . FLOAT

# %% [markdown]
# Python называет любое число с десятичной точкой float. Этот термин используется в большинстве языков программирования и относится к тому факту, что десятичная точка может стоять в любой позиции числа. Каждый язык программирования должен быть тщательно разработан для правильного управления десятичными числами, чтобы числа вели себя соответствующим образом независимо от того, где находится десятичная точка.
#
# По большей части вы можете использовать десятичные дроби, не беспокоясь о том, как они себя ведут. Просто введите числа, которые вы хотите использовать, и Python, скорее всего, сделает то, что вы ожидаете:

# %%
0.5 + 0.3
# Out:
# 0.8

# %%
5 / 2
# Out:
# 2.5

# %%
5 // 2
# Out:
# 2

# %%
1 / 3
# Out:
# 0.3333333333333333

# %% [markdown]
# Но имейте в виду, что иногда вы можете получить в своем ответе произвольное количество десятичных знаков:

# %%
0.3 + 0.3 + 0.3
# Out:
# 0.8999999999999999

# %% [markdown]
# Питоновский float это аналог сишного double, т.е. формат числа с плавающей точкой. Упомянутая  погрешность это не погрешность питона или другого языка, это проблема всех типов форматов хранения числа с плавающей точкой. Просто некоторые программы автоматически округляют хвосты и это не заметно. Используйте round(x,n) и будет вам счастье. А еще в питоне есть  decimal(формат с фиксированным числом знаков после запятой) и  fractions (число задается в виде дроби)

# %%
0.3 + 0.3 + 0.3 == 0.9
# Out:
# False

# %%
9 ** 0.5
# Out:
# 3.0

# %%
5e-1
# Out:
# 0.5

# %%
1234e2
# Out:
# 123400.0

# %%
5+5
# Out:
# 10

# %%
float(5) +5
# Out:
# 10.0

# %%
int(5.0) +5
# Out:
# 10

# %%
int(5.0) +5.0
# Out:
# 10.0

# %%
7/3
# Out:
# 2.3333333333333335

# %%
type(7)
# Out:
# int

# %%
type(7.0)
# Out:
# float

# %%
type(True)
# Out:
# bool

# %%
type(true)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-6f4d8242c3d0> in <cell line: 0>()
# ----> 1 type(true)
#
# NameError: name 'true' is not defined

# %% [markdown]
# ## ПРАКТИКА

# %%
1) Найдите остаток от деления 77 на 2

# %%
print(77%2)
# Out:
# 1

# %%
2) Узнайте четное ли число 22

# %%
print(22 % 2 == 0)
# Out:
# True

# %%
3) Посчитайте 86 в степени 7

# %%
print(86**7)
# Out:
# 34792782221696

# %%
4) Найдите квадратный корень из 3686400

# %%
import math
print(math.sqrt(3686400))
# Out:
# 1920.0

# %% [markdown]
# ## ДЗ

# %% [markdown]
# ##### Установить:
#     1) Редактор кода (например sublime)
#     2) jupyter notebook (wsl или анаконда)

# %% [markdown]
# **Установлен редактор кода vs code, а также установлен jupyter notebook**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
